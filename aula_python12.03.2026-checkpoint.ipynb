# %% [markdown]
# Crie um programa que:
# 1. Peça a idade do usuário.
# 2. Mostre na tela:
#  Criança (se for menor de 13 anos)
#  Adolescente (de 13 a 17 anos)
#  Adulto (18 anos ou mais)
# Dica: Use as estruturas if, elif e else.

# %%
idade = int(input("Digite sua idade"))
if idade <=13:
    print("Criança")
elif idade >=17:
    print("adolecente")
else:
    print("adulto")
# Out:
# Digite sua idade 36
# adolecente

# %% [markdown]
# 1. Verificar número positivo
# Peça ao usuário um número e verifique: Se o número for
# maior que 0, mostre "Número positivo". (Use apenas
# if).

# %%
numero = float(input("Digite um número: "))
if numero > 0:
    print("Número positivo")
# Out:
# Digite um número:  5
# Número positivo

# %% [markdown]
# 2. Verificar maior de idade
# Peça a idade do usuário. Mostre "Maior de idade" se a
# idade for maior ou igual a 18. (Use apenas if).

# %%
idade = int(input("Digite a sua idade: "))
if idade >= 18:
    print("Maior de idade")
# Out:
# Digite a sua idade:  18
# Maior de idade

# %% [markdown]
# 3. Número maior que 10
# Peça um número ao usuário. Se o número for maior que
# 10, mostre "Número maior que 10". (Use apenas if).

# %%
numero = float(input("Digite um número: "))
if numero > 10:
    print("Número maior que 10")
# Out:
# Digite um número:  45
# Número maior que 10

# %% [markdown]
# 4. Par ou Ímpar
# Peça um número inteiro. Mostre "Número par" ou
# "Número ímpar". (Use if e else).

# %%
numero = int(input("Digite um número inteiro: "))

if numero % 2 == 0:
    print("Número par")
else:
    print("Número ímpar")

# %% [markdown]
# 5. Aprovação de aluno
# Peça a nota do aluno. Se a nota for maior ou igual a 7,
# mostre "Aluno aprovado". Caso contrário, mostre "Aluno
# reprovado". (Use if e else).

# %%
nota = float(input("Digite a nota do aluno: "))


if nota >= 7:
    print("Aluno aprovado")
else:
    print("Aluno reprovado")
# Out:
# Digite a nota do aluno:  2
# Aluno reprovado

# %% [markdown]
# 6. Comparar dois números
# Peça dois números ao usuário. Mostre qual é maior.
# Exemplo: "O maior número é 25". (Use if e else).

# %%
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))


if num1 > num2:
    print(f"O maior número é {num1}")
else:
    print(f"O maior número é {num2}")
# Out:
# Digite o primeiro número:  27
# Digite o segundo número:  28
# O maior número é 28.0

# %% [markdown]
# 7. Classificação de idade
# Peça a idade da pessoa. Mostre:
# ▶ Criança (0–12)
# ▶ Adolescente (13–17)
# ▶ Adulto (18 ou mais)
# (Use if, elif e else).

# %%
idade = int(input("Digite a sua idade: "))


if idade <= 12:
    print(" Criança")
elif idade <= 17:
    print(" Adolescente")
else:
    print("Adulto")
# Out:
# Digite a sua idade:  13
# ▶ Adolescente

# %% [markdown]
# 8. Nota do aluno
# Peça a nota do aluno. Mostre:
# ▶ Aprovado (nota ≥ 7)
# ▶ Recuperação (nota entre 5 e 6)
# ▶ Reprovado (nota < 5)
# (Use if, elif e else).

# %%
nota = float(input("Digite a nota do aluno: "))

if nota >= 7:
    print(" Aprovado")
elif nota >= 5:
    print("Recuperação")
else:
    print(" Reprovado")
# Out:
# Digite a nota do aluno:  7
#  Aprovado

# %% [markdown]
# 9. Comparar três números
# Peça três números. Mostre qual é o maior deles.
# Exemplo: "O maior número é 42".

# %%
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))
n3 = float(input("Digite o terceiro número: "))


maior = n1

if n2 > maior:
    maior = n2

if n3 > maior:
    maior = n3


print(f"O maior número é {maior}")
# Out:
# Digite o primeiro número:  23
# Digite o segundo número:  23
# Digite o terceiro número:  34
# O maior número é 34.0

# %% [markdown]
# 10. Sistema simples de login
# Peça ao usuário nome e senha. Considere:
# ▶ usuario_correto = "admin"
# ▶ senha_correta = "1234"
# Se os dados estiverem corretos, mostre "Login
# realizado com sucesso". Caso contrário, "Usuário ou
# senha incorretos". (Use o operador ==).

# %%
usuario_correto = "admin"
senha_correta = "1234"

usuario = input("Digite o nome de usuário: ")
senha = input("Digite a senha: ")

if usuario == usuario_correto and senha == senha_correta:
    print("Login realizado com sucesso")
else:
    print("Usuário ou senha incorretos")
# Out:
# Digite o nome de usuário:  hebert123
# Digite a senha:  hebert123
# Usuário ou senha incorretos

# %% [markdown]
# Desafio Extra
#
# Crie um programa que peça um número e mostre:
# ▶ Número positivo
# ▶ Número negativo
# ▶ Número igual a zero
# Dica: Use as estruturas if, elif e else para resolver
# esse problema.

# %%
numero = float(input("Digite um número: "))


if numero > 0:
    print("Número positivo")
elif numero < 0:
    print(" Número negativo")
else:
    print(" Número igual a zero")
