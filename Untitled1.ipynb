# %% [markdown]
# exemplos

# %%
#verificação de maioridade
idade_usuario = int(input("Digite sua idade"))
idade_usuario
# Out:
# Digite sua idade 18
# 18

# %%
if idade_usuario >=18:
    print("Voce tem idade para entrar")
else:
    print("Voce não pode entrar")
# Out:
# Voce tem idade para entrar

# %% [markdown]
# #verificar a aprovação do aluno ou não

# %%
nota = int(input("Digite sua nota"))
nota
# Out:
# Digite sua nota 5
# 5

# %%
if nota >=6:
    print("aprovado")
elif nota >=5:
    print("recuperação")
else:
    print("reprovada")
# Out:
# recuperação

# %% [markdown]
# #verificação " ==" "e !="

# %%
numero_digitado = float(input("Digite um numero entre -2 e 5 n/ "))
numero_digitado
# Out:
# Digite um numero entre -2 e 5 n/  3
# 3.0

# %%
if numero_digitado == -1:
    print("Você acertou")

else:
    print ("Que pena, tente novamente")
# Out:
# Que pena, tente novamente

# %%
if numero_digitado != 3:
    print("Que pena, tente novamente")
else:
    print("Voce acertou!")
# Out:
# Voce acertou!

# %%
# resto de divisão por numero "%"
# par ou impar

numero = int(input("Digite um numero natural"))
if numero%2 == 0:
   print("f 0 numero é par!")
else:
   print("f 0 numero é impar")
# Out:
# Digite um numero natural 1000
# f 0 numero é par!

# %%
#comparar 2 numeros

numero1 = float(input("Digite o primeiro numero"))
numero2 = float(input("Digite o segundo numero"))
if numero1 > numero2:
   print(f" numero1 > numero2")

elif numero1 == numer2:
    print(f" numero1 = numero2")
else:
   print(f" {numero2}> {numero1}")
# Out:
# Digite o primeiro numero 45
# Digite o segundo numero 7
#  numero1 > numero2

# %%
# reolvendo uma equacação de segundo grau
a = float(input("digite o valor do coeficinete a"))
b = float(input("digite o valor do coeficinete b"))
c = float(input("digite o valor do coeficinete c"))
delta = b**2 - 4*a*c
x1 = (-b + delta**(0.5))/(2*a)
x2 = (-b - delta**(0.5))/(2*a)
if delta < 0:
    print(f"delta menor que zero:{delta}")
    print("não há raíz real")
elif a == 0:
   print(f"{a} é menor que zero, imsira um número difrente de zero")
   
elif delta == 0:
     print(f" x'= x''={x2}")
else: 
     print(f"x'= {x1} e x''={x2}")
# Out:
# digite o valor do coeficinete a 1
# digite o valor do coeficinete b -5
# digite o valor do coeficinete c 6
# x'= 3.0 e x''=2.0

# %%
0
