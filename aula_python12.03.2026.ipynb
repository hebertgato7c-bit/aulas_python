# %% [markdown]
# EXERCICIO 1 : CRIE UM PROGRAMA QUE MOSTRE NA TELA

# %%
a = "Eu estou aprendendo paython"
print(a)
# Out:
# Eu estou aprendendo paython

# %%
b = "Eu estou aprendendo paython"
a = "Quero aprender a programar e vender e ganhar muito dinheiro"
print(b)
print(a)
# Out:
# Eu estou aprendendo paython
# Quero aprender a programar e vender e ganhar muito dinheiro

# %%
u = "meu mome é hebert"
v = "eu moro em goiania"
print(u)
print(v)
# Out:
# meu mome é hebert
# eu moro em goiania

# %%
nome_do_aluno = "Hebert"
idade_do_aluno = "17"
print(" Meu nome é ",nome_do_aluno, "e tenho",idade_do_aluno, "anos.")
# Out:
#  Meu nome é  Hebert e tenho 17 anos.

# %%
a = "barcelona"
b = "catalunha"
c =  "espanha"
print("eu moro em ", a,b,c,)
# Out:
# eu moro em  barcelona catalunha espanha

# %%
entrada = input("Digite seu nome:")
cidade = input("Qual a cidade que voce mora:")
print( "Ola", entrada, "voce mora em", cidade,)
# Out:
# Digite seu nome: hebert
# Qual a cidade que voce mora: espanha
# Ola hebert voce mora em espanha
